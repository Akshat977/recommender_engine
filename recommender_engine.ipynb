# %%
import numpy as np
import pandas as pd

# %% [raw]
# -------------------------------A RECOMMENDER ENGINE WHICH SUGGESTS MOVIES BASED ON FOLLOWING CONDITIONS:---------------------------------------
# 1  SUGGESTING MOVIES WITH THE HIGHEST POPULARITY + RATING(WHICH HAS NOT YET BEEN WATCHED)
# 2. SUGGESTING MOVIES BASED ON CONTENT PREVIOUSLY WATCHED AND ALSO PREDICT THE RATING FOR THE NEW MOVIES BASED ON THE USER

# %%
#IMPORTING DATASETS
df_first=pd.read_csv('tmdb_5000_movies.csv')
df_second=pd.read_csv('movies.csv')
df_third=pd.read_csv('ratings.csv')

# %%
#----------------------------------------CONDITION 1--------------------------------------------------------------------
#enter movie names and rating for movies previously watched
#names
names=['Batman v Superman: Dawn of Justice','Captain America: Civil War','Guardians of the Galaxy']

# %%
df_first.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df_first_cleaned=df_first[['id','popularity','vote_average','vote_count']]
df_first_cleaned.head()
# Out:
#        id  popularity  vote_average  vote_count
# 0   19995  150.437577           7.2       11800
# 1     285  139.082615           6.9        4500
# 2  206647  107.376788           6.3        4466
# 3   49026  112.312950           7.6        9106
# 4   49529   43.926995           6.1        2124

# %%
R=df_first_cleaned['vote_average']
v=df_first_cleaned['vote_count']
C=df_first_cleaned['vote_average'].mean()
m=df_first_cleaned['vote_count'].quantile(0.70)
df_first_cleaned['W']=((R*v)+(C*m))/(v+m)
# Out:
# C:\Users\aksha\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#check for null values
df_first_cleaned.isnull().sum()
# Out:
# id              0
# popularity      0
# vote_average    0
# vote_count      0
# W               0
# dtype: int64

# %%
#now bring popularity and W to the same scale
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaled=scaler.fit_transform(df_first_cleaned[['popularity','W']])
df_first_scaled=pd.DataFrame(scaled)
df_first_scaled.columns=['popularity','W']

# %%
#dropping from df_cleaned and concatenating these:
df_first_cleaned.drop(['popularity','W'],axis=1,inplace=True)
df_first_cleaned=pd.concat([df_first_cleaned,df_first_scaled],axis=1)
df_first_cleaned.head()
# Out:
# C:\Users\aksha\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        id  vote_average  vote_count  popularity         W
# 0   19995           7.2       11800    0.171815  0.674339
# 1     285           6.9        4500    0.158846  0.581403
# 2  206647           6.3        4466    0.122635  0.436273
# 3   49026           7.6        9106    0.128272  0.773054
# 4   49529           6.1        2124    0.050169  0.387739

# %%
#calculating the column score which has 50% weightage of W and 50% of popularity. Then, add the score column to the original dataframe
score=(df_first_cleaned['popularity']*0.5)+(df_first_cleaned['W']*0.5)
score=pd.DataFrame(score)
score.columns=['score']
df_first=pd.concat([df_first,score],axis=1)
df_first.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#sort the whole dataset acc. to score column
df_first.sort_values('score',ascending=False,inplace=True)
df_first.head()
# Out:
#         budget                                             genres  \
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                      homepage      id  \
# 95          http://www.interstellarmovie.net/  157336
# 546              http://www.minionsmovie.com/  211672
# 94                http://marvel.com/guardians  118340
# 788  http://www.foxmovies.com/movies/deadpool  293660
# 127               http://www.madmaxmovie.com/   76341
#
#                                               keywords original_language  \
# 95   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
# ...

# %%
#now check from input list and display 5 movies the user has not yet seen
c=0
for index,row in df_first.iterrows():
    if c==5:
        break
    if(row['title'] not in names):
        print(row['title'])
        c+=1
# Out:
# Interstellar
# Minions
# Deadpool
# Mad Max: Fury Road
# The Shawshank Redemption

# %% [raw]
# ---------------------------------------CONDITION 2[CONTENT-BASED RECOMMENDER]-------------------------------------------------------------

# %%
names[0]='Batman: The Dark Knight Returns, Part 1'
print(names)
# Out:
# ['Batman: The Dark Knight Returns, Part 1', 'Captain America: Civil War', 'Guardians of the Galaxy']

# %%
df_second.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#removing year from the title of the movies
#title_new,names
title_new=list()
for index,row in df_second.iterrows():
    x=row['title']
    try:
        i=x.index('(')
    except:
        continue
    title_new.append(row['title'][:i])
title_new=pd.DataFrame(title_new)  
df_second.drop(['title'],axis=1,inplace=True)
title_new.columns=['title']
df_second=pd.concat([df_second,title_new],axis=1)
df_second.head()
# Out:
#    movieId                                       genres  \
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# 1        2                   Adventure|Children|Fantasy
# 2        3                               Comedy|Romance
# 3        4                         Comedy|Drama|Romance
# 4        5                                       Comedy
#
#                           title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
#separating the genre and storing them as a list
df_second['genres']=df_second.genres.str.split('|')
df_second.head()
# Out:
#    movieId                                             genres  \
# 0        1  [Adventure, Animation, Children, Comedy, Fantasy]
# 1        2                     [Adventure, Children, Fantasy]
# 2        3                                  [Comedy, Romance]
# 3        4                           [Comedy, Drama, Romance]
# 4        5                                           [Comedy]
#
#                           title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
#finding the genres of input names
df=df_second.iloc[:5,:]
print(df)
# Out:
#    movieId                                             genres  \
# 0        1  [Adventure, Animation, Children, Comedy, Fantasy]
# 1        2                     [Adventure, Children, Fantasy]
# 2        3                                  [Comedy, Romance]
# 3        4                           [Comedy, Drama, Romance]
# 4        5                                           [Comedy]
#
#                           title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II

# %%
names=['Father of the Bride Part II','Waiting to Exhale','Grumpier Old Men']
rating=[2,10,8]
rating=np.array(rating)

# %%
#encoding the titles according to different genres
Comedy=list()
Drama=list()
Romance=list()
for index,row in df_second.iterrows():
    if 'Comedy' in row['genres']:
        Comedy.append(1)
    else:
        Comedy.append(0)
    if 'Drama' in row['genres']:
        Drama.append(1)
    else:
        Drama.append(0)
    if 'Romance' in row['genres']:
        Romance.append(1)
    else:
        Romance.append(0)

# %%
#adding them to original dataframe
df_second=pd.concat([df_second,pd.DataFrame(Comedy,columns=['Comedy'])],axis=1)
df_second=pd.concat([df_second,pd.DataFrame(Drama,columns=['Drama'])],axis=1)
df_second=pd.concat([df_second,pd.DataFrame(Romance,columns=['Romance'])],axis=1)

# %%
df_calc=df_second[['genres','title','Comedy','Drama','Romance']]
df_calc=df_calc.iloc[2:5,:]
df_calc=df_calc[['Comedy','Drama','Romance']]
df_calc.head()
# Out:
#    Comedy  Drama  Romance
# 2       1      0        1
# 3       1      1        1
# 4       1      0        0

# %%
#multiply encoded and rating to obtain user profile
df_calc=df_calc.mul(rating,axis=0)
user_profile=list()
user_profile.append(df_calc['Comedy'].sum())
user_profile.append(df_calc['Drama'].sum())
user_profile.append(df_calc['Romance'].sum())
user_profile
#the above is a row vector
# Out:
# [20, 10, 12]

# %%
#multiplying the user profile to the columns comedy, drama and romance in the original dataset:
df_second['Comedy']=df_second['Comedy']*user_profile[0]
df_second['Drama']=df_second['Drama']*user_profile[1]
df_second['Romance']=df_second['Romance']*user_profile[2]

# %%
#now forming a new column from the row-wise aggregate :
df_second['score']=df_second['Comedy']+df_second['Romance']+df_second['Drama']

# %%
#sorting the dataset acc. to the score:
df_second.sort_values('score',ascending=False,inplace=True)
df_second['score']=df_second['score']/10

# %%
#NOW YOU CAN SELECT THE TOP MOVIES FROM ABOVE WIT THEIR SPECIFIED SCORE(PREDICTED RATING)

# %%
df_second.head()
# Out:
#        movieId                    genres                     title  Comedy  \
# 823        838  [Comedy, Drama, Romance]                     Emma       20
# 16395    82597  [Comedy, Drama, Romance]             Titanic Town       20
# 11000    45100  [Comedy, Drama, Romance]          American Dreamz       20
# 23144   109853  [Comedy, Drama, Romance]          Entre ses mains       20
# 23120   109773  [Comedy, Drama, Romance]  Dick Figures: The Movie       20
#
#        Drama  Romance  score
# 823       10       12    4.2
# 16395     10       12    4.2
# 11000     10       12    4.2
# 23144     10       12    4.2
# 23120     10       12    4.2
